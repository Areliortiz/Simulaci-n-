# %% [markdown]
# <a href="https://colab.research.google.com/github/Areliortiz/Simulaci-n-/blob/main/Media_muestral.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importamos las librerías
import random as rnd
import numpy as np
import matplotlib.pyplot as plt

# %%
def media(inferior,superior,N_1):
  inferior=a
  superior=b
  N_1=N
  suma=0
  lista=[]
  for i in range(N):
    U=rnd.uniform(0,1)
    Xi=a+(U*+(b-a))
    g = np.sqrt(np.arctan(Xi))
    lista.append(g)
    suma=suma+g
  est=(b-a)*(1/N)*suma
  return lista

# %%
#generamos el experimento
lista =media(0,1,1000)
media=np.mean(lista) #Calcula la media
print(media)
desve=np.std(lista) #Calcula la desviación estándar
print(desve)
# Out:
# 0.5843717145603406
# 0.23219689787090636

# %%
plt.plot(lista)                      #grafica la lista completa
plt.axhline(desve,color="red")
plt.axvline(media,color="green")
plt.show()

# %%
#generamos la simulacion del experimento
def simulación (N):             # crea funcion para generar la simulacion del experimento
   r=[]
   for i in range(N):
      R_1=media(0,1,50)
      r.append(R_1[-1])
   return r

# %%
#creamos histograma
S=simulación (1000) #generamos distribucion
plt.hist(S)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-809b21973286> in <cell line: 2>()
#       1 #creamos histograma
# ----> 2 S=simulación (1000) #generamos distribucion
#       3 plt.hist(S)
#
# <ipython-input-45-dd787b5c372d> in simulación(N)
#       3    r=[]
#       4    for i in range(N):
# ----> 5       R_1=media(0,1,50)
#       6       r.append(R_1[-1])
#       7    return r
#
# TypeError: 'numpy.float64' object is not callable
