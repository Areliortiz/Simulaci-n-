# %% [markdown]
# <a href="https://colab.research.google.com/github/Areliortiz/Simulaci-n-/blob/main/circulo_pi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as rnd
import numpy as np
import matplotlib.pyplot as plt

# %%
def circulo(N):
  #x=np.linspace (0,1,1000)
  n = 0
  contador = 0
  lista = []
  for i in range(N):
    u1=rnd.random()
    u2=rnd.random()
   # plt.scatter(u1,u2,color='red')
    if u2 <= np.sqrt(1-u1**2):
      contador += 1
      n = n+ 1
    prob = contador / (i + 1)
    lista.append(4*prob)


  pi= 4*(n/N)
 # print(pi)
 # plt.plot(x,np.sqrt(1-x**2))
 # plt.show( )
# return lista  # da la gráfica del estado estacionario
  return lista[-1]

# %%
listas= circulo(1000)
media= np.mean(listas)
des=np.std(listas)

# %%
plt.plot(listas)
plt.axvline(media,color="green")
plt.show()

# %% [markdown]
# Para modificar la función y convertirla en una corrida de la simulación: lista-->lista[-1] y fijarnos N=500(por ejemplo)

# %%
def simulación (M):
   r=[]
   for i in range(M):
      R=circulo (500)
      r.append(R)
   return r

# %%
S=simulación (1000)
plt.hist(S)
# Out:
# (array([  1.,   3.,  32.,  78., 234., 297., 205., 120.,  25.,   5.]),
#  array([2.848 , 2.9016, 2.9552, 3.0088, 3.0624, 3.116 , 3.1696, 3.2232,
#         3.2768, 3.3304, 3.384 ]),
#  <BarContainer object of 10 artists>)
