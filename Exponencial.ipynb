# %% [markdown]
# <a href="https://colab.research.google.com/github/Areliortiz/Simulaci-n-/blob/main/Exponencial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as rnd
import numpy as np
import matplotlib.pyplot as plt
#n=10
#lam=2
#l= -1/lam

# %%
def expo(lam=2,n=10):
    l= -1/lam
    #lam,n= 2,10
    list=[]
    for i in range(n):
        u=rnd.random()
        x=(l*np.log(u))
        list.append(x)
    return list

# %%
#ejercicio
def expo(a=10,b=15):
    list=[]
    for i in range(100):
        u=rnd.random()
        x=((b-a)*u)+a
        list.append(x)
    return list

# %%
#usa el algoritmo
g= expo(10,15)
print(g)
# Out:
# [14.9868898618381, 12.318082734453203, 14.484669353279102, 12.935589977101282, 14.591556986371632, 11.916481201821522, 13.924647910152359, 10.855951624801799, 11.500985628672002, 13.76344676729607, 10.82523432486499, 11.541281460660688, 12.505858456118183, 10.031699038112302, 12.755108181297054, 14.0073435319206, 14.508941175146813, 10.771363342761653, 10.05456019429144, 10.923207065675232, 14.106135492844384, 10.863283289955136, 13.797012148553982, 14.178881649527074, 12.408166445860706, 14.829123977967285, 11.841966308893445, 10.773644026346695, 10.527465540329318, 14.86270158661721, 12.540206448072738, 13.194964049584582, 11.29458135812121, 10.506787970780369, 11.458812822926081, 10.296734519048329, 11.121710031743463, 10.796711018216813, 14.24126815366536, 11.575971083641178, 13.68733495504799, 14.961177097497274, 14.43868402088938, 13.244612525894542, 12.157682737328534, 12.952698834111981, 12.779900935541821, 10.066184861787805, 11.794864933503302, 11.630806886683473, 11.391784764552702, 10.512881546639118, 14.419665578037346, 11.564174939463578, 12.6090467948464, 13.998009771919774, 14.04106391274328, 12.557230165244697, 13.789163010050622, 14.737210631201153, 12.00440682470876, 13.474001563864057, 12.478749434513944, 11.792753227974824, 10.785417685495528, 14.604758938847638, 11.315570544624217, 14.933303654191889, 13.089102487989628, 13.042141166329568, 11.337929621812389, 10.787552589277093, 14.452920516923914, 12.094215273761627, 10.630358584451132, 13.481635038718025, 10.15518131641742, 10.15506986906172, 12.205426292813037, 10.706234628955977, 10.646021683313124, 12.011979040592458, 14.309139926441453, 13.8505442358524, 11.251479989362387, 12.748467913413817, 13.206713946547172, 11.106872924707979, 14.1429668620316, 10.454256875006365, 14.013858611028741, 13.800833464119998, 14.481519256070001, 13.077303750571067, 10.36851758629673, 13.051950756011282, 11.39885372145206, 12.01992114281709, 10.722777602989714, 13.080015323168924]

# %%
#calcula media
mu=np.mean(g)
print(mu)
# Out:
# 12.45023929514843

# %%
#calcula varianza
sigma=np.var(g)
print(sigma)
# Out:
# 2.205936803884708

# %%
plt.plot(g)
#grafica, imprime valores de g
#sucesion

# %%
plt.hist(g,bins=50)
#imprime histograma
#densidad
#bins, modifica ancho de las barras
# Out:
# (array([3., 2., 1., 1., 3., 1., 4., 5., 4., 0., 2., 0., 3., 3., 2., 3., 1.,
#         2., 1., 3., 2., 2., 0., 2., 2., 2., 1., 3., 0., 2., 5., 1., 2., 0.,
#         2., 0., 1., 3., 2., 1., 4., 3., 1., 1., 5., 1., 2., 1., 2., 3.]),
#  array([10.03169904, 10.13080285, 10.22990667, 10.32901049, 10.4281143 ,
#         10.52721812, 10.62632194, 10.72542575, 10.82452957, 10.92363339,
#         11.0227372 , 11.12184102, 11.22094484, 11.32004865, 11.41915247,
#         11.51825629, 11.6173601 , 11.71646392, 11.81556773, 11.91467155,
#         12.01377537, 12.11287918, 12.211983  , 12.31108682, 12.41019063,
#         12.50929445, 12.60839827, 12.70750208, 12.8066059 , 12.90570972,
#         13.00481353, 13.10391735, 13.20302117, 13.30212498, 13.4012288 ,
#         13.50033261, 13.59943643, 13.69854025, 13.79764406, 13.89674788,
#         13.9958517 , 14.09495551, 14.19405933, 14.29316315, 14.39226696,
#         14.49137078, 14.5904746 , 14.68957841, 14.78868223, 14.88778605,
#         14.98688986]),
#  <BarContainer object of 50 artists>)

# %%
#Acumulada

# %%
def cdf(g):
  n=len(g)
  x=np.sort(g)
  y=np.arange(0,n)/n
  return x,y

# %%
x,y=cdf(g)

# %%
plt.step(x,y)
#media
plt.axvline(mu,color="green")
#mediana
plt.axhline(.5,color="red")
